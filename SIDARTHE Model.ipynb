# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from covid19dh import covid19
from scipy.integrate import odeint

# %%
##Import the data

x_ind, src_ind = covid19("IND")
x_chn, src_chn = covid19("CHN")
x_jpn, src_jpn = covid19("JPN")
x_swe, src_ind = covid19("SWE")
x_ita, src_ita = covid19("ITA")
x_fra, src_fra = covid19("FRA")
# Out:
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.
# We have invested a lot of time and effort in creating COVID-19 Data Hub, please cite the following when using it:
#
# 	Guidotti, E., Ardia, D., (2020), "COVID-19 Data Hub", Journal of Open Source Software 5(51):2376, doi: 10.21105/joss.02376.
#
# A BibTeX entry for LaTeX users is
#
# 	@Article{,
# 		title = {COVID-19 Data Hub},
# 		year = {2020},
# 		doi = {10.21105/joss.02376},
# 		author = {Emanuele Guidotti and David Ardia},
# 		journal = {Journal of Open Source Software},
# 		volume = {5},
# 		number = {51},
# 		pages = {2376},
# 	}
#
# To hide this message use 'verbose = False'.

# %%
x_ita
# Out:
#         id       date       tests  confirmed  recovered   deaths     hosp  \
# 25660  ITA 2020-01-22         NaN        NaN        NaN      NaN      NaN
# 25661  ITA 2020-01-23         NaN        NaN        NaN      NaN      NaN
# 25662  ITA 2020-01-24         NaN        NaN        NaN      NaN      NaN
# 25663  ITA 2020-01-25         NaN        NaN        NaN      NaN      NaN
# 25664  ITA 2020-01-26         NaN        NaN        NaN      NaN      NaN
# ...    ...        ...         ...        ...        ...      ...      ...
# 25943  ITA 2020-10-31  15784461.0   679430.0   289426.0  38618.0  19809.0
# 25944  ITA 2020-11-01  15967918.0   709335.0   292380.0  38826.0  20841.0
# 25945  ITA 2020-11-02  16103649.0   731588.0   296017.0  39059.0  21862.0
# 25946  ITA 2020-11-03  16285936.0   759829.0   302275.0  39412.0  23339.0
# 25947  ITA 2020-11-04  16497767.0   790377.0   307378.0  39764.0  24408.0
#
#        vent     icu  population  ...  currency  administrative_area_level  \
# 25660   NaN     NaN    60421760  ...       EUR                          1
# 25661   NaN     NaN    60421760  ...       EUR                          1
# 25662   NaN     NaN    60421760  ...       EUR                          1
# 25663   NaN     NaN    60421760  ...       EUR                          1
# 25664   NaN     NaN    60421760  ...       EUR                          1
# ...     ...     ...         ...  ...       ...                        ...
# 25943   NaN  1843.0    60421760  ...       EUR                          1
# 25944   NaN  1939.0    60421760  ...       EUR                          1
# 25945   NaN  2022.0    60421760  ...       EUR                          1
# 25946   NaN  2225.0    60421760  ...       EUR                          1
# 25947   NaN  2292.0    60421760  ...       EUR                          1
#
#        administrative_area_level_1  administrative_area_level_2  \
# 25660                        Italy                          NaN
# 25661                        Italy                          NaN
# 25662                        Italy                          NaN
# 25663                        Italy                          NaN
# 25664                        Italy                          NaN
# ...                            ...                          ...
# 25943                        Italy                          NaN
# 25944                        Italy                          NaN
# 25945                        Italy                          NaN
# 25946                        Italy                          NaN
# 25947                        Italy                          NaN
#
#        administrative_area_level_3  latitude  longitude  key  \
# 25660                          NaN      43.0       12.0  NaN
# 25661                          NaN      43.0       12.0  NaN
# 25662                          NaN      43.0       12.0  NaN
# 25663                          NaN      43.0       12.0  NaN
# 25664                          NaN      43.0       12.0  NaN
# ...                            ...       ...        ...  ...
# 25943                          NaN      43.0       12.0  NaN
# 25944                          NaN      43.0       12.0  NaN
# 25945                          NaN      43.0       12.0  NaN
# 25946                          NaN      43.0       12.0  NaN
# 25947                          NaN      43.0       12.0  NaN
#
#        key_apple_mobility  key_google_mobility
# 25660               Italy                   IT
# 25661               Italy                   IT
# 25662               Italy                   IT
# 25663               Italy                   IT
# 25664               Italy                   IT
# ...                   ...                  ...
# 25943               Italy                   IT
# 25944               Italy                   IT
# 25945               Italy                   IT
# 25946               Italy                   IT
# 25947               Italy                   IT
#
# [288 rows x 35 columns]

# %%
population=60421760

Y = x_ind.iloc[61:,4].values #Stores Daily Confirmed
